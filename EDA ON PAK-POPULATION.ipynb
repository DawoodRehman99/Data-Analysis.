# %% [markdown]
# **Dataset Overview:**
# This dataset contains demographic data from the 2017 Pakistan Population Census. It provides detailed information on population distribution across provinces, divisions, districts, and sub-divisions. Key details include urban and rural populations, gender distribution, transgender individuals, sex ratios, population figures from 1998, and annual growth rates.
#
# Key Features:
#
# *Province: Administrative regions where data was collected.
# Division: Second-level administrative units within provinces.
# District: Larger administrative areas within divisions.
# Sub-Division: Localized areas (tehsils) within districts.
# Area: Land area of each sub-division (in square kilometers).
# Urban Population 2017: Urban population per sub-division in 2017.
# Rural Population 2017: Rural population per sub-division in 2017.
# Male & Female Population 2017: Gender-specific population data.
# Transgender Population 2017: Transgender population per sub-division.
# Sex Ratio 2017: Number of females per 1000 males in each sub-division.
# Population 1998: Population recorded in the 1998 census.
# Annual Growth Rate: Population growth rate from 1998 to 2017.
# Source: Official reports from the Pakistan Population Census.*
#
# Usage: Researchers can use this data to analyze demographic trends, population growth, and gender distribution at different levels of Pakistan’s administrative structure. Ensure proper attribution and compliance with legal guidelines.

# %% [markdown]
# **IMPORTING ESSENTIAL LIBRARIES.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pak_population_data=pd.read_csv("sub-division_population_of_pakistan.csv")
pak_population_data
# Out:
#      PROVINCE                   DIVISION                   DISTRICT  \
# 0      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 1      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 2      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 3      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# 4      PUNJAB        BAHAWALPUR DIVISION      BAHAWALNAGAR DISTRICT
# ..        ...                        ...                        ...
# 523  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 524  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 525  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 526  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
# 527  KPK/FATA  DERA ISMAIL KHAN DIVISION  SOUTH WAZIRISTAN DISTRICT
#
#             SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0    BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA).

# %%
pak_population_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PROVINCE                    528 non-null    object
#  1   DIVISION                    528 non-null    object
#  2   DISTRICT                    528 non-null    object
#  3   SUB DIVISION                528 non-null    object
#  4   AREA (sq.km)                528 non-null    float64
#  5   ALL SEXES (RURAL)           528 non-null    int64
#  6   MALE (RURAL)                528 non-null    int64
#  7   FEMALE (RURAL)              528 non-null    int64
#  8   TRANSGENDER (RURAL)         528 non-null    int64
#  9   SEX RATIO (RURAL)           528 non-null    float64
#  10  AVG HOUSEHOLD SIZE (RURAL)  528 non-null    float64
#  11  POPULATION 1998 (RURAL)     528 non-null    int64
#  12  ANNUAL GROWTH RATE (RURAL)  528 non-null    float64
# ...

# %% [markdown]
# *The code shows that the DataFrame has **528 rows** and **21 columns**. It lists the names of each column and their corresponding data types, which include integers (`int64`), floats (`float64`), and objects (text data).*

# %%
pak_population_data.columns
# Out:
# Index(['PROVINCE', 'DIVISION', 'DISTRICT', 'SUB DIVISION', 'AREA (sq.km)',
#        'ALL SEXES (RURAL)', 'MALE (RURAL)', 'FEMALE (RURAL)',
#        'TRANSGENDER (RURAL)', 'SEX RATIO (RURAL)',
#        'AVG HOUSEHOLD SIZE (RURAL)', 'POPULATION 1998 (RURAL)',
#        'ANNUAL GROWTH RATE (RURAL)', 'ALL SEXES (URBAN)', 'MALE (URBAN)',
#        'FEMALE (URBAN)', 'TRANSGENDER (URBAN)', 'SEX RATIO (URBAN)',
#        'AVG HOUSEHOLD SIZE (URBAN)', 'POPULATION 1998 (URBAN)',
#        'ANNUAL GROWTH RATE (URBAN)'],
#       dtype='object')

# %%
pak_population_data.isnull().sum()
# Out:
# PROVINCE                      0
# DIVISION                      0
# DISTRICT                      0
# SUB DIVISION                  0
# AREA (sq.km)                  0
# ALL SEXES (RURAL)             0
# MALE (RURAL)                  0
# FEMALE (RURAL)                0
# TRANSGENDER (RURAL)           0
# SEX RATIO (RURAL)             0
# AVG HOUSEHOLD SIZE (RURAL)    0
# POPULATION 1998 (RURAL)       0
# ANNUAL GROWTH RATE (RURAL)    0
# ALL SEXES (URBAN)             0
# MALE (URBAN)                  0
# FEMALE (URBAN)                0
# TRANSGENDER (URBAN)           0
# SEX RATIO (URBAN)             0
# AVG HOUSEHOLD SIZE (URBAN)    0
# POPULATION 1998 (URBAN)       0
# ANNUAL GROWTH RATE (URBAN)    0
# dtype: int64

# %% [markdown]
# **There is no missing value or null value in a Dataset.**

# %%
# maximum column printing option
pd.set_option('display.max_columns', None) # None means all.
# maximum row printing option
pd.set_option('display.max_rows', None)

# %% [markdown]
# This code configures the pandas library to display all columns and rows in a DataFrame output, ensuring no data is hidden during data analysis.

# %%
df = pd.DataFrame(pak_population_data)
#df #thats print all the dataset expecially use for debugging.

# %%
pak_population_data.describe().T
# Out:
#                             count           mean            std  min  \
# AREA (sq.km)                528.0    1492.005871    2039.453778  0.0
# ALL SEXES (RURAL)           528.0  246278.011364  271189.816559  0.0
# MALE (RURAL)                528.0  125275.687500  137563.021458  0.0
# FEMALE (RURAL)              528.0  120984.149621  133716.898296  0.0
# TRANSGENDER (RURAL)         528.0      18.174242      25.522248  0.0
# SEX RATIO (RURAL)           528.0      98.982614      26.812660  0.0
# AVG HOUSEHOLD SIZE (RURAL)  528.0       6.277064       2.074947  0.0
# POPULATION 1998 (RURAL)     528.0  167427.994318  178388.976993  0.0
# ANNUAL GROWTH RATE (RURAL)  528.0       3.124792       9.577872  0.0
# ALL SEXES (URBAN)           528.0  140863.528409  351246.279136  0.0
# MALE (URBAN)                528.0   72843.386364  182349.241379  0.0
# FEMALE (URBAN)              528.0   67997.865530  168872.528212  0.0
# TRANSGENDER (URBAN)         528.0      22.276515      66.068127  0.0
# ...

# %% [markdown]
# Summary Statistics:
#
# ### Key Insights:
#
# 1. **Geographical Areas**:
#    - The average area of regions is approximately **1492 sq.km**, but there is significant variability (STD = **2039.45 sq.km**), indicating some areas are much larger or smaller than average.
#
# 2. **Rural Population**:
#    - The average total population in rural areas is about **246,278** individuals, with a high standard deviation (**271,189.82**). This suggests substantial differences in population sizes across rural regions, ranging from **0** to as high as **2,297,375**.
#
# 3. **Gender Distribution**:
#    - **Male Population (Rural)**: The average is **125,276**, but some districts have as few as **27,127** males, while others have up to **1,172,995**.
#    - **Female Population (Rural)**: Averages around **120,984**. The variability is also high, indicating disparities in gender distribution.
#    - The **Transgender Population (Rural)** is small, with an average of just **18** individuals.
#
# 4. **Sex Ratio**:
#    - The overall **sex ratio** in rural areas averages **98.98** males for every 100 females, with variability indicating some areas may have significant gender imbalances.
#
# 5. **Household Size**:
#    - Average household size in rural areas is about **6.28** members, suggesting relatively large family sizes.
#
# 6. **Urban Population**:
#    - In urban areas, the average population is lower at around **140,863**, with a wider spread (STD = **351,246.28**), indicating some urban areas are much more populous than others.
#
# 7. **Annual Growth Rates**:
#    - The annual growth rate for rural populations averages **3.12%**, while urban growth is lower at **1.92%**. This suggests rural areas are experiencing faster population growth.
#
# 8. **Historical Population (1998)**:
#    - The average population recorded in 1998 for rural areas was **167,428**, indicating a growth trend over the years.
#
# ### Summary:
# This dataset reveals substantial disparities in population distribution across regions in Pakistan, with notable differences between urban and rural areas, as well as among genders. The insights on growth rates and household sizes suggest evolving demographic trends that could influence policy and planning.

# %% [markdown]
# ### We Have Explored Numerical Insights; Now Let's Visualize Outliers and Distributions Through Plots.

# %%
box_plots_per_figure = 4  


for i in range(0, len(pak_population_data.select_dtypes(include=['float64', 'int64']).columns), box_plots_per_figure):
    plt.figure(figsize=(15, 10))
    
 
    for j, column in enumerate(pak_population_data.select_dtypes(include=['float64', 'int64']).columns[i:i + box_plots_per_figure]):
        plt.subplot(2, 2, j + 1)
        pak_population_data.boxplot(column=column)
        
        mean_value = pak_population_data[column].mean()
        plt.axhline(mean_value, color='red', linestyle='--', label='Mean')
        
        plt.title(column)
        plt.ylabel('Values')
        plt.legend()
    
    plt.tight_layout()  
    plt.show()

# %% [markdown]
# ###  Province Area with Boxplot.

# %%
def get_total_area_by_province(province_name):
    total_area = pak_population_data[pak_population_data['PROVINCE'] == province_name]['AREA (sq.km)'].sum()
    return total_area
province =['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK']
# Loop through each province and display the total area
for province_name in province:
    total_area_in_province = get_total_area_by_province(province_name)
    print(f"Total area of {province_name}: {total_area_in_province} sq.km")
# Out:
# Total area of PUNJAB: 202693.0 sq.km
# Total area of SINDH: 140136.0 sq.km
# Total area of BALOCHISTAN: 345464.0 sq.km
# Total area of KPK: 74957.1 sq.km

# %%
sns.boxplot(x='PROVINCE', y='AREA (sq.km)', data=pak_population_data)
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='AREA (sq.km)'>

# %%
#sns.countplot(x='PROVINCE',  data=pak_population_data)

# %% [markdown]
# ### ANNUAL GROWTH RATE (URBAN) then (RURAL)

# %%
sns.barplot(x='PROVINCE', y='ANNUAL GROWTH RATE (URBAN)', data=pak_population_data)
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='ANNUAL GROWTH RATE (URBAN)'>

# %%
sns.barplot(x='PROVINCE', y='ANNUAL GROWTH RATE (RURAL)', data=pak_population_data)
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='ANNUAL GROWTH RATE (RURAL)'>

# %% [markdown]
# **Number Of Divisions across Provinces With Plot**.

# %%
def count_divisions_by_provinces(province_names):
    counts = {province: pak_population_data[pak_population_data['PROVINCE'] == province]['DIVISION'].nunique() 
              for province in province_names}
    return counts

province_names = ['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK']
division_counts = count_divisions_by_provinces(province_names)

for province, count in division_counts.items():
    print(f"Number of divisions in {province}: {count}")
# Out:
# Number of divisions in PUNJAB: 9
# Number of divisions in SINDH: 7
# Number of divisions in BALOCHISTAN: 5
# Number of divisions in KPK: 7

# %%
division_counts = pak_population_data.groupby('PROVINCE')['DIVISION'].nunique().reset_index()

division_counts.columns = ['PROVINCE', 'DIVISION_COUNT']

plt.figure(figsize=(10, 6))
sns.barplot(x='PROVINCE', y='DIVISION_COUNT', data=division_counts, palette='viridis')
plt.title('Number of Divisions by Province')
plt.xlabel('Province')
plt.ylabel('Number of Divisions')
plt.xticks(rotation=45)  
plt.show()

# %% [markdown]
# **This plot shows the number of subdivisions within each division.**

# %%
plt.figure(figsize=(17, 8))
sns.countplot(x='DIVISION', data=pak_population_data)
plt.title('Count of Entries by Province')
plt.xlabel('Province')
plt.ylabel('Count')
plt.xticks(rotation=60)  
plt.show()

# %% [markdown]
#  **Number Of District across Provinces With Plot**.

# %%
def count_district_by_provinces(province_names):
    counts = {province: pak_population_data[pak_population_data['PROVINCE'] == province]['DISTRICT'].nunique() 
              for province in province_names}
    return counts

province_names = ['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK']
district_counts = count_divisions_by_provinces(province_names)

for province, count in district_counts.items():
    print(f"Number of Districts in {province}: {count}")
# Out:
# Number of Districts in PUNJAB: 9
# Number of Districts in SINDH: 7
# Number of Districts in BALOCHISTAN: 5
# Number of Districts in KPK: 7

# %%
district_counts = pak_population_data.groupby('PROVINCE')['DISTRICT'].nunique().reset_index()

district_counts.columns = ['PROVINCE', 'DISTRICT_COUNT']

plt.figure(figsize=(10, 6))
sns.barplot(x='PROVINCE', y='DISTRICT_COUNT', data=district_counts, palette='Reds')
plt.title('Number of District by Province')
plt.xlabel('Province')
plt.ylabel('Number of Districts')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
#  **Number Of Sub-Division across Provinces With Plot**.

# %%
def count_divisions_by_provinces(province_names):
    counts = {province: pak_population_data[pak_population_data['PROVINCE'] == province]['SUB DIVISION'].nunique() 
              for province in province_names}
    return counts

province_names = ['PUNJAB', 'SINDH', 'BALOCHISTAN', 'KPK']
SubDivision_counts = count_divisions_by_provinces(province_names)

for province, count in SubDivision_counts.items():
    print(f"Number of Sub-Divisions in {province}: {count}")
# Out:
# Number of Sub-Divisions in PUNJAB: 143
# Number of Sub-Divisions in SINDH: 137
# Number of Sub-Divisions in BALOCHISTAN: 131
# Number of Sub-Divisions in KPK: 71

# %%
district_counts = pak_population_data.groupby('PROVINCE')['SUB DIVISION'].nunique().reset_index()

district_counts.columns = ['PROVINCE', 'SUB DIVISION']

plt.figure(figsize=(10, 6))
sns.barplot(x='PROVINCE', y='SUB DIVISION', data=district_counts, palette='Blues')
plt.title('Number of SUB DIVISION by Province')
plt.xlabel('Province')
plt.ylabel('Number of SUB DIVISION')
plt.xticks(rotation=45) 
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='PROVINCE', data=pak_population_data)
plt.title('Count of Entries by Province')
plt.xlabel('Province')
plt.ylabel('Count')
plt.xticks(rotation=45)  
plt.show()

# %%
# Count the number of unique sub-divisions per province
sub_division_counts = df.groupby('PROVINCE')['SUB DIVISION'].nunique()

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sub_division_counts, labels=sub_division_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Sub-Divisions by Province')
plt.axis('equal')  
plt.show()

# %%
pak_population_data.groupby(["PROVINCE","DIVISION"]).size()
# Out:
# PROVINCE     DIVISION
# BALOCHISTAN  Kalat Division                  18
#              Makran Division                 37
#              Naseerabad Division             19
#              Quetta Division                 38
#              Zhob Division                   19
# KPK          BANNU DIVISION                   4
#              DERA ISMAIL KHAN DIVISION        6
#              HAZARA DIVISION                 15
#              KOHAT DIVISION                   7
#              MALAKAND DIVISION               26
#              MARDAN DIVISION                  7
#              PESHAWAR DIVISION                6
# KPK/FATA     BANNU DIVISION                  11
#              DERA ISMAIL KHAN DIVISION        9
#              KOHAT DIVISION                   7
#              MALAKAND DIVISION                7
#              PESHAWAR DIVISION               12
# PUNJAB       BAHAWALPUR DIVISION             15
#              D.G.KHAN DIVISION               14
# ...

# %% [markdown]
# This Tab shows Provices and there Divisions and numerical nnumber represents count of rows or Sub-divisions..

# %%
pak_population_data.groupby(["PROVINCE","AREA (sq.km)","DIVISION"]).size()
# Out:
# PROVINCE     AREA (sq.km)  DIVISION
# BALOCHISTAN  0.0           Zhob Division                   4
#              83.0          Quetta Division                 1
#              137.0         Naseerabad Division             1
#              174.0         Quetta Division                 1
#              205.0         Quetta Division                 1
#              231.0         Quetta Division                 1
#              258.0         Quetta Division                 1
#              259.0         Quetta Division                 1
#              277.0         Naseerabad Division             1
#              331.0         Naseerabad Division             1
#              334.0         Naseerabad Division             1
#              399.0         Naseerabad Division             1
#              402.0         Naseerabad Division             1
#              413.0         Quetta Division                 1
#              418.0         Quetta Division                 1
# ...

# %% [markdown]
# This Tab also shows Provices, there Area size, Divisions name and numerical nnumber represents count of rows..,

# %% [markdown]
# ### In this we can see RURAL Population According there Province.

# %% [markdown]
# The first two tables represent the total **RURAL population**, along with the mean and standard deviation (STD) for each province. The next table visualizes the mean **RURAL population** by province.

# %%
pak_population_data.groupby("PROVINCE")["ALL SEXES (RURAL)"].agg(['sum','mean','std'])
# Out:
#                   sum           mean            std
# PROVINCE
# BALOCHISTAN   8879634   67783.465649   88614.464905
# KPK          24892840  350603.380282  310891.698961
# KPK/FATA      4587753   99733.760870   88467.441515
# PUNJAB       68662922  480160.293706  316266.369963
# SINDH        23011641  167968.182482  115641.388202

# %%
#we know barplots working on mean.
plt.figure(figsize=(10, 6))
sns.barplot(x='PROVINCE', y='ALL SEXES (RURAL)', data=pak_population_data, palette="husl")
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='ALL SEXES (RURAL)'>

# %% [markdown]
# ### In this we can see URBAN Population according there Province.

# %% [markdown]
# The first two tables represent the total **URBAN population**, along with the mean and standard deviation (STD) for each province. The next table visualizes the mean **URBAN population** by province.

# %%
pak_population_data.groupby("PROVINCE")["ALL SEXES (URBAN)"].agg(['sum','mean','std'])
# Out:
#                   sum           mean            std
# PROVINCE
# BALOCHISTAN   3406701   26005.351145   92781.820458
# KPK           5605071   78944.661972  239868.306619
# KPK/FATA       139866    3040.565217   11432.891225
# PUNJAB       40391671  282459.237762  571056.110647
# SINDH        24832634  181260.102190  236297.632000

# %%
#we know barplots working on mean.
plt.figure(figsize=(10, 6))
sns.barplot(x='PROVINCE', y='ALL SEXES (URBAN)', data=pak_population_data, palette="Reds")
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='ALL SEXES (URBAN)'>

# %%
pak_population_data.head(10)
# Out:
#   PROVINCE             DIVISION               DISTRICT  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 5   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 6   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 7   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 8   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 9   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
#
#                SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0       BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1          CHISHTIAN TEHSIL        1500.0             540342        273788
# 2         FORT ABBAS TEHSIL        2536.0             361240        182655
# ...

# %% [markdown]
# **RURAL Population was in 2017.**

# %%
print(f'Total RURAL Population of Pakistan in 2017 was : {pak_population_data["ALL SEXES (RURAL)"].sum()}')
# Out:
# Total RURAL Population of Pakistan in 2017 was : 130034790

# %% [markdown]
# **URBAN Population was in 2017.**

# %%
print(f'Total URBAN Population of Pakistan in 2017 was : {pak_population_data["ALL SEXES (URBAN)"].sum()}')
# Out:
# Total URBAN Population of Pakistan in 2017 was : 74375943

# %% [markdown]
# **PAK-Population in 2017**

# %%
pop_R=pak_population_data["ALL SEXES (RURAL)"].sum()
pop_U=pak_population_data["ALL SEXES (URBAN)"].sum()
T_pop= pop_R+pop_U
print(f"Total PAK-Population in 2017 was :{T_pop} ")
# Out:
# Total PAK-Population in 2017 was :204410733

# %% [markdown]
# **RURAL Population was in 1998.**

# %%
print(f'Total RURAL Population of Pakistan in 1998 was : {pak_population_data["POPULATION 1998 (RURAL)"].sum()}')
# Out:
# Total RURAL Population of Pakistan in 1998 was : 88401981

# %% [markdown]
# **URBAN Population was in 1998.**

# %%
print(f'Total URBAN Population of Pakistan in 1998 was : {pak_population_data["POPULATION 1998 (URBAN)"].sum()}')
# Out:
# Total URBAN Population of Pakistan in 1998 was : 42316331

# %% [markdown]
# **PAK-Population in 1998.**

# %%
pop_R98 =pak_population_data["POPULATION 1998 (RURAL)"].sum()
pop_U98 =pak_population_data["POPULATION 1998 (URBAN)"].sum()
pop1998=(pop_R98 + pop_U98)
print(f"Total Pakistan-Population in 1998 was :{pop1998}")
# Out:
# Total Pakistan-Population in 1998 was :130718312

# %% [markdown]
# #### NOW CHECKING GROWTH OF POPULATION 1998 to 2017.

# %%
print(f"Growth Of Population 1998 to 2017 at 'RURAL' side was: {pop_R - pop_R98}") 
print(f"Growth Of Population 1998 to 2017 at 'URBAN' side was: {pop_U - pop_U98}") 
print("")
print(f"Total Growth Of 'PAKISTAN' Population 1998 to 2017 : {T_pop - pop1998}")
# Out:
# Growth Of Population 1998 to 2017 at 'RURAL' side was: 41632809
# Growth Of Population 1998 to 2017 at 'URBAN' side was: 32059612
#
# Total Growth Of 'PAKISTAN' Population 1998 to 2017 : 73692421

# %% [markdown]
# ### Now Visualize this.

# %%
data=pd.DataFrame({
    "Year" : [2017, 2017, 1998, 1998],
    "Population" : [130034790, 74375943, 88401981, 42316331],
    "Area" : ["Rural", "Urban", "Rural", "Urban"]
})
plt.figure(figsize=(5, 5))
sns.barplot(x='Year', y='Population', hue='Area', data=data)
plt.title('Population by Year and Area')
plt.xlabel('Year')
plt.ylabel('Population')
plt.show()

# %%
print("Original DataFrame size:", pak_population_data.shape)
# Out:
# Original DataFrame size: (528, 21)

# %% [markdown]
# ### Identify and Remove outliers

# %%
sns.boxplot(x='PROVINCE', y='AREA (sq.km)', data=pak_population_data)
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='AREA (sq.km)'>

# %% [markdown]
# The data shows several outliers across provinces, with Balochistan having the most, reaching up to 17,500 sq. km. Balochistan also has a large interquartile range (IQR), indicating high variability in area sizes, while Sindh and Punjab show more consistency with smaller IQRs. KPK and KPK/FATA have the smallest IQRs, suggesting minimal variation in area sizes. The higher median area size in Balochistan suggests generally larger areas than other provinces, where medians indicate smaller, more consistent area sizes.

# %%
# Assuming your DataFrame is named 'df' and the relevant columns are 'PROVINCE' and 'AREA'
q1 = df.groupby('PROVINCE')['AREA (sq.km)'].quantile(0.25)
q3 = df.groupby('PROVINCE')['AREA (sq.km)'].quantile(0.75)
print(q1)
print(q3)
# Out:
# PROVINCE
# BALOCHISTAN    858.0
# KPK            400.5
# KPK/FATA       250.0
# PUNJAB         699.5
# SINDH          276.0
# Name: AREA (sq.km), dtype: float64
# PROVINCE
# BALOCHISTAN    3446.0
# KPK            1278.0
# KPK/FATA        595.5
# PUNJAB         1715.5
# SINDH          1018.0
# Name: AREA (sq.km), dtype: float64

# %%
iqr = q3 - q1
print(iqr)
# Out:
# PROVINCE
# BALOCHISTAN    2588.0
# KPK             877.5
# KPK/FATA        345.5
# PUNJAB         1016.0
# SINDH           742.0
# Name: AREA (sq.km), dtype: float64

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
print(lower_bound)
print(upper_bound)
# Out:
# PROVINCE
# BALOCHISTAN   -3024.00
# KPK            -915.75
# KPK/FATA       -268.25
# PUNJAB         -824.50
# SINDH          -837.00
# Name: AREA (sq.km), dtype: float64
# PROVINCE
# BALOCHISTAN    7328.00
# KPK            2594.25
# KPK/FATA       1113.75
# PUNJAB         3239.50
# SINDH          2131.00
# Name: AREA (sq.km), dtype: float64

# %%
# Merging lower and upper bounds back into the original DataFrame
df = df.merge(lower_bound, on='PROVINCE', suffixes=('', '_lower'))
df = df.merge(upper_bound, on='PROVINCE', suffixes=('', '_upper'))

# %%
# Removing outliers
df_no_outliers = df[(df['AREA (sq.km)'] >= df['AREA (sq.km)_lower']) & (df['AREA (sq.km)'] <= df['AREA (sq.km)_upper'])]

# Dropping the temporary bound columns
df_no_outliers = df_no_outliers.drop(columns=['AREA (sq.km)_lower', 'AREA (sq.km)_upper'])

# %%
print("Original DataFrame size:", df.shape)
print("DataFrame size after removing outliers:", df_no_outliers.shape)
# Out:
# Original DataFrame size: (528, 23)
# DataFrame size after removing outliers: (484, 21)

# %% [markdown]
# **Now you can see Data having Minimum Outliers.**

# %%
sns.boxplot(x='PROVINCE', y='AREA (sq.km)', data=df_no_outliers, hue='PROVINCE')
# Out:
# <AxesSubplot: xlabel='PROVINCE', ylabel='AREA (sq.km)'>
